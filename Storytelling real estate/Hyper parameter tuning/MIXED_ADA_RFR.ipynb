# %%
from google.colab import drive
import pandas as pd

# This will prompt for authorization to access your Google Drive
drive.mount('/content/drive')

# Update the file path to the location where you uploaded your CSV in Google Drive
file_path = '/content/drive/My Drive/Thesis/df-englisch_cat.csv'

# Read the CSV file
df = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from ast import literal_eval

df = df.drop(df.columns[0], axis=1)


df["ada_embedding_eng"] = df["ada_embedding_eng"].apply(literal_eval).apply(np.array)

# Separating the target variable and embeddings
x = df["ada_embedding_eng"]
y = df['numerical_price']

# Dropping the 'ada_embedding_eng' column from df
z = df.drop(["ada_embedding_eng", "numerical_price"], axis=1)

# Deleting original dataframe for memory purpose
del df

# Explode the embedding arrays into separate columns
x = x.apply(pd.Series)

# Concatenating the exploded embeddings with the rest of the data
concatenated_df = pd.concat([x, z], axis=1).reset_index(drop=True)
concatenated_df.columns = concatenated_df.columns.astype(str)


x_train, x_test, y_train, y_test = train_test_split(concatenated_df, y, test_size=0.2, random_state=42)
# Now, sample 10000 instances from the remaining training set for hyperparameter tuning
x_train = x_train.sample(10000, random_state=42)
y_train = y_train.loc[x_train.index]

# %%
# !pip install optuna
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np
import optuna

def Objective_rf_cat(trial):
    # Parameters
    max_depth = trial.suggest_int("max_depth", 2, 50, log=True)
    n_estimators = trial.suggest_int("n_estimators", 100, 1000, step=50)
    max_features = trial.suggest_categorical("max_features", ['log2', 'sqrt',])
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 2, 25, step=2)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 25, step=2)
    bootstrap = trial.suggest_categorical("bootstrap", [True, False])

    rf_params = dict(max_depth=max_depth, n_estimators=n_estimators,
                     max_features=max_features, min_samples_leaf=min_samples_leaf,
                     min_samples_split=min_samples_split, bootstrap=bootstrap)

    clf_rf_opt = RandomForestRegressor(**rf_params, n_jobs=-1)

    # StandardScaler for y
    scaler = StandardScaler()

    # KFold Cross-validation
    kf = KFold(n_splits=5)
    r2_scores = []

    for train_index, test_index in kf.split(x_train):
        X_train_fold, X_test_fold = x_train.iloc[train_index], x_train.iloc[test_index]
        y_train_fold, y_test_fold = y_train.iloc[train_index], y_train.iloc[test_index]

        # Scaling y_train
        y_train_scaled = scaler.fit_transform(np.array(y_train_fold).reshape(-1, 1)).flatten()


        # Fitting the model
        clf_rf_opt.fit(X_train_fold, y_train_scaled)

        # Predicting and inverse transformation
        y_pred_scaled = clf_rf_opt.predict(X_test_fold)
        y_pred = scaler.inverse_transform(np.array(y_pred_scaled).reshape(-1, 1)).flatten()


        # R2 Score
        r2 = r2_score(y_test_fold, y_pred)
        r2_scores.append(r2)

    return float(np.mean(r2_scores))
# Out:
# Collecting optuna
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 6.7 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 9.9 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.0 alembic-1.13.1 colorlog-6.8.0 optuna-3.5.0

# %%
study_rf = optuna.create_study(directions=['maximize'])
study_rf.optimize(Objective_rf_cat, n_trials=50)
# Out:
# [I 2024-01-06 16:23:55,994] A new study created in memory with name: no-name-a0a96aa4-d196-4dd8-88e7-8d51bcbf396e
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:25:55,198] Trial 0 finished with value: 0.29706978695919084 and parameters: {'max_depth': 19, 'n_estimators': 350, 'max_features': 'log2', 'min_samples_leaf': 22, 'min_samples_split': 12, 'bootstrap': False}. Best is trial 0 with value: 0.29706978695919084.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:33:38,722] Trial 1 finished with value: 0.36886660848474867 and parameters: {'max_depth': 8, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 18, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 1 with value: 0.36886660848474867.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:34:18,456] Trial 2 finished with value: 0.2757986369189422 and parameters: {'max_depth': 24, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 20, 'min_samples_split': 4, 'bootstrap': True}. Best is trial 1 with value: 0.36886660848474867.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:34:52,875] Trial 3 finished with value: 0.30634045955885647 and parameters: {'max_depth': 24, 'n_estimators': 150, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 1 with value: 0.36886660848474867.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:35:56,127] Trial 4 finished with value: 0.27896843015221057 and parameters: {'max_depth': 8, 'n_estimators': 250, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 12, 'bootstrap': False}. Best is trial 1 with value: 0.36886660848474867.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:38:29,158] Trial 5 finished with value: 0.32862228641049546 and parameters: {'max_depth': 6, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 22, 'bootstrap': True}. Best is trial 1 with value: 0.36886660848474867.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:41:09,733] Trial 6 finished with value: 0.41136747701101345 and parameters: {'max_depth': 10, 'n_estimators': 150, 'max_features': 'sqrt', 'min_samples_leaf': 18, 'min_samples_split': 16, 'bootstrap': False}. Best is trial 6 with value: 0.41136747701101345.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:42:17,039] Trial 7 finished with value: 0.3738830905350349 and parameters: {'max_depth': 45, 'n_estimators': 150, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 6 with value: 0.41136747701101345.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:43:04,575] Trial 8 finished with value: 0.24310602258317604 and parameters: {'max_depth': 7, 'n_estimators': 300, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 6 with value: 0.41136747701101345.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:43:51,772] Trial 9 finished with value: 0.3138950975913512 and parameters: {'max_depth': 13, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 16, 'bootstrap': True}. Best is trial 6 with value: 0.41136747701101345.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:46:38,835] Trial 10 finished with value: 0.1434218554180997 and parameters: {'max_depth': 2, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 16, 'min_samples_split': 18, 'bootstrap': False}. Best is trial 6 with value: 0.41136747701101345.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:55:59,448] Trial 11 finished with value: 0.4125748468025561 and parameters: {'max_depth': 48, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 24, 'min_samples_split': 24, 'bootstrap': False}. Best is trial 11 with value: 0.4125748468025561.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:02:05,136] Trial 12 finished with value: 0.20723581963434165 and parameters: {'max_depth': 3, 'n_estimators': 900, 'max_features': 'sqrt', 'min_samples_leaf': 24, 'min_samples_split': 24, 'bootstrap': False}. Best is trial 11 with value: 0.4125748468025561.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:11:34,299] Trial 13 finished with value: 0.40998275868644535 and parameters: {'max_depth': 37, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 24, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 11 with value: 0.4125748468025561.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:16:00,173] Trial 14 finished with value: 0.2658819266389568 and parameters: {'max_depth': 4, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 16, 'min_samples_split': 16, 'bootstrap': False}. Best is trial 11 with value: 0.4125748468025561.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:29:34,851] Trial 15 finished with value: 0.41885396817150033 and parameters: {'max_depth': 14, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 20, 'min_samples_split': 24, 'bootstrap': False}. Best is trial 15 with value: 0.41885396817150033.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:43:01,665] Trial 16 finished with value: 0.4123616952979875 and parameters: {'max_depth': 15, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 22, 'min_samples_split': 24, 'bootstrap': False}. Best is trial 15 with value: 0.41885396817150033.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:02:47,140] Trial 17 finished with value: 0.43607010160966075 and parameters: {'max_depth': 32, 'n_estimators': 950, 'max_features': 'sqrt', 'min_samples_leaf': 14, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 17 with value: 0.43607010160966075.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:23:52,119] Trial 18 finished with value: 0.4373830552017348 and parameters: {'max_depth': 27, 'n_estimators': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 14, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 18 with value: 0.4373830552017348.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:45:33,180] Trial 19 finished with value: 0.4440874603954567 and parameters: {'max_depth': 31, 'n_estimators': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 12, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 19 with value: 0.4440874603954567.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 19:07:05,001] Trial 20 finished with value: 0.4441906902529542 and parameters: {'max_depth': 30, 'n_estimators': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 12, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 20 with value: 0.4441906902529542.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 19:28:48,932] Trial 21 finished with value: 0.44233576169381517 and parameters: {'max_depth': 27, 'n_estimators': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 12, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 20 with value: 0.4441906902529542.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 19:48:09,499] Trial 22 finished with value: 0.4531399529458545 and parameters: {'max_depth': 19, 'n_estimators': 850, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 18, 'bootstrap': False}. Best is trial 22 with value: 0.4531399529458545.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 20:08:33,320] Trial 23 finished with value: 0.46051109345567953 and parameters: {'max_depth': 19, 'n_estimators': 850, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 23 with value: 0.46051109345567953.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 20:28:26,818] Trial 24 finished with value: 0.45952432546092525 and parameters: {'max_depth': 16, 'n_estimators': 850, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 23 with value: 0.46051109345567953.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 20:49:40,470] Trial 25 finished with value: 0.4669659689868645 and parameters: {'max_depth': 19, 'n_estimators': 850, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 25 with value: 0.4669659689868645.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 21:06:20,042] Trial 26 finished with value: 0.44801618560306833 and parameters: {'max_depth': 11, 'n_estimators': 800, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 25 with value: 0.4669659689868645.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 21:26:33,689] Trial 27 finished with value: 0.4600310371199832 and parameters: {'max_depth': 19, 'n_estimators': 850, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 25 with value: 0.4669659689868645.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 21:42:37,760] Trial 28 finished with value: 0.4816860929999317 and parameters: {'max_depth': 20, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 28 with value: 0.4816860929999317.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 21:58:35,174] Trial 29 finished with value: 0.478337076633277 and parameters: {'max_depth': 19, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 12, 'bootstrap': False}. Best is trial 28 with value: 0.4816860929999317.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 22:05:07,774] Trial 30 finished with value: 0.3092676465049454 and parameters: {'max_depth': 5, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 28 with value: 0.4816860929999317.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 22:16:50,478] Trial 31 finished with value: 0.4871302920754103 and parameters: {'max_depth': 21, 'n_estimators': 400, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 31 with value: 0.4871302920754103.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 22:27:40,550] Trial 32 finished with value: 0.4813448503911168 and parameters: {'max_depth': 22, 'n_estimators': 400, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 31 with value: 0.4871302920754103.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 22:36:33,927] Trial 33 finished with value: 0.4629431182385984 and parameters: {'max_depth': 12, 'n_estimators': 400, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 31 with value: 0.4871302920754103.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 22:43:47,702] Trial 34 finished with value: 0.4483090052439354 and parameters: {'max_depth': 36, 'n_estimators': 400, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'bootstrap': True}. Best is trial 31 with value: 0.4871302920754103.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 22:46:52,312] Trial 35 finished with value: 0.3770257354121047 and parameters: {'max_depth': 23, 'n_estimators': 400, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 31 with value: 0.4871302920754103.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 22:57:37,980] Trial 36 finished with value: 0.452117989544358 and parameters: {'max_depth': 23, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 31 with value: 0.4871302920754103.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:00:16,140] Trial 37 finished with value: 0.30390621654473887 and parameters: {'max_depth': 9, 'n_estimators': 550, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 12, 'bootstrap': False}. Best is trial 31 with value: 0.4871302920754103.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:08:03,629] Trial 38 finished with value: 0.4486911166490034 and parameters: {'max_depth': 17, 'n_estimators': 450, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 31 with value: 0.4871302920754103.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:29:45,425] Trial 39 finished with value: 0.49256991022499685 and parameters: {'max_depth': 41, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 39 with value: 0.49256991022499685.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:35:20,196] Trial 40 finished with value: 0.38058611211612614 and parameters: {'max_depth': 41, 'n_estimators': 700, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 39 with value: 0.49256991022499685.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:54:40,861] Trial 41 finished with value: 0.48895317430926993 and parameters: {'max_depth': 24, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 39 with value: 0.49256991022499685.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 00:13:54,372] Trial 42 finished with value: 0.4897126538460608 and parameters: {'max_depth': 25, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 39 with value: 0.49256991022499685.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 00:34:01,887] Trial 43 finished with value: 0.4967757715281323 and parameters: {'max_depth': 49, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 43 with value: 0.4967757715281323.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 00:57:18,774] Trial 44 finished with value: 0.4956645071912605 and parameters: {'max_depth': 49, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 43 with value: 0.4967757715281323.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 01:12:46,945] Trial 45 finished with value: 0.4658244674402633 and parameters: {'max_depth': 50, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'bootstrap': True}. Best is trial 43 with value: 0.4967757715281323.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 01:17:00,801] Trial 46 finished with value: 0.3548058430093032 and parameters: {'max_depth': 41, 'n_estimators': 650, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 43 with value: 0.4967757715281323.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 01:40:26,127] Trial 47 finished with value: 0.4968814590861762 and parameters: {'max_depth': 36, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 47 with value: 0.4968814590861762.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 02:03:50,022] Trial 48 finished with value: 0.495335071385418 and parameters: {'max_depth': 43, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 47 with value: 0.4968814590861762.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 02:16:01,573] Trial 49 finished with value: 0.4398691393075721 and parameters: {'max_depth': 34, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 4, 'bootstrap': True}. Best is trial 47 with value: 0.4968814590861762.

# %%
optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# Out:
# <ipython-input-6-934d0b211bde>:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# <Axes: title={'center': 'Optimization History Plot'}, xlabel='Trial', ylabel='Objective Value'>

# %%
from optuna.visualization import matplotlib as optuna_matplotlib
import matplotlib.pyplot as plt
# Plot the optimization history in a different format
optuna.visualization.matplotlib.plot_optimization_history(study_rf)

optuna_matplotlib.plot_optimization_history(study_rf)

plt.ylim(0, 1)

plt.show()
# Out:
# <ipython-input-7-1eb49e18946d>:4: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# <ipython-input-7-1eb49e18946d>:6: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna_matplotlib.plot_optimization_history(study_rf)
