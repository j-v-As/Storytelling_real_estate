# %%
from google.colab import drive
import pandas as pd

# This will prompt for authorization to access your Google Drive
drive.mount('/content/drive')

# Update the file path to the location where you uploaded your CSV in Google Drive
file_path = '/content/drive/My Drive/Thesis/df-W2V.csv'

# Read the CSV file
df = pd.read_csv(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from ast import literal_eval



df["word2vec_embeddings"] = df["word2vec_embeddings"].apply(literal_eval).apply(np.array)

x = df["word2vec_embeddings"]
y = df['numerical_price']
###### deleting original dataframe for memory purpose ####
del df

# Explode the embedding arrays into separate rows
x = x.apply(pd.Series)
# First split: separate out a test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Now, sample 10000 instances from the remaining training set for hyperparameter tuning
x_train = x_train.sample(10000, random_state=42)
y_train = y_train.loc[x_train.index]

# %%
x_train = x_train.to_numpy()
x_test = x_test.to_numpy()
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# Ensure y_train and y_test are 1D arrays
# This step is only necessary if y_train or y_test are not already 1D arrays
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

# Check the shapes again after any necessary adjustments
print("Adjusted y_train shape:", y_train.shape)
print("Adjusted y_test shape:", y_test.shape)
# Out:
# Adjusted y_train shape: (10000,)
# Adjusted y_test shape: (14403,)

# %%
# !pip install optuna
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np
import optuna

def Objective_rf(trial):
    # Parameters
    max_depth = trial.suggest_int("max_depth", 2, 50, log=True)
    n_estimators = trial.suggest_int("n_estimators", 100, 1000, step=50)
    max_features = trial.suggest_categorical("max_features", ['log2', 'sqrt',])
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 2, 25, step=2)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 25, step=2)
    bootstrap = trial.suggest_categorical("bootstrap", [True, False])

    rf_params = dict(max_depth=max_depth, n_estimators=n_estimators,
                     max_features=max_features, min_samples_leaf=min_samples_leaf,
                     min_samples_split=min_samples_split, bootstrap=bootstrap)

    clf_rf_opt = RandomForestRegressor(**rf_params, n_jobs=-1)

    # StandardScaler for y
    scaler = StandardScaler()

    # KFold Cross-validation
    kf = KFold(n_splits=5)
    r2_scores = []

    for train_index, test_index in kf.split(x_train):
        X_train_fold, X_test_fold = x_train[train_index], x_train[test_index]
        y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]

        # Scaling y_train
        y_train_scaled = scaler.fit_transform(y_train_fold.reshape(-1, 1)).flatten()

        # Fitting the model
        clf_rf_opt.fit(X_train_fold, y_train_scaled)

        # Predicting and inverse transformation
        y_pred_scaled = clf_rf_opt.predict(X_test_fold)
        y_pred = scaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

        # R2 Score
        r2 = r2_score(y_test_fold, y_pred)
        r2_scores.append(r2)

    return float(np.mean(r2_scores))
# Out:
# Collecting optuna
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 3.3 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 20.1 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.0 alembic-1.13.1 colorlog-6.8.0 optuna-3.5.0

# %%
study_rf = optuna.create_study(directions=['maximize'])
study_rf.optimize(Objective_rf, n_trials=50)
# Out:
# [I 2024-01-07 10:46:05,423] A new study created in memory with name: no-name-6eea4943-de2c-4c5f-971d-e99c93cc9427
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 10:47:59,949] Trial 0 finished with value: 0.23127101463517138 and parameters: {'max_depth': 7, 'n_estimators': 200, 'max_features': 'sqrt', 'min_samples_leaf': 18, 'min_samples_split': 12, 'bootstrap': False}. Best is trial 0 with value: 0.23127101463517138.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 10:51:57,471] Trial 1 finished with value: 0.25022100110610757 and parameters: {'max_depth': 12, 'n_estimators': 800, 'max_features': 'log2', 'min_samples_leaf': 18, 'min_samples_split': 18, 'bootstrap': False}. Best is trial 1 with value: 0.25022100110610757.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 10:56:40,123] Trial 2 finished with value: 0.27630585020523923 and parameters: {'max_depth': 35, 'n_estimators': 850, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 2 with value: 0.27630585020523923.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:01:55,192] Trial 3 finished with value: 0.20155303032758579 and parameters: {'max_depth': 6, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 2 with value: 0.27630585020523923.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:03:39,873] Trial 4 finished with value: 0.14031745125915138 and parameters: {'max_depth': 5, 'n_estimators': 600, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 2 with value: 0.27630585020523923.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:04:13,997] Trial 5 finished with value: 0.24292650616275457 and parameters: {'max_depth': 15, 'n_estimators': 150, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 24, 'bootstrap': True}. Best is trial 2 with value: 0.27630585020523923.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:04:37,761] Trial 6 finished with value: 0.0688643663799007 and parameters: {'max_depth': 2, 'n_estimators': 200, 'max_features': 'sqrt', 'min_samples_leaf': 14, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 2 with value: 0.27630585020523923.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:05:37,844] Trial 7 finished with value: 0.2827135846954715 and parameters: {'max_depth': 31, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 18, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 7 with value: 0.2827135846954715.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:06:39,025] Trial 8 finished with value: 0.2619215415133593 and parameters: {'max_depth': 40, 'n_estimators': 150, 'max_features': 'sqrt', 'min_samples_leaf': 14, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 7 with value: 0.2827135846954715.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:08:28,755] Trial 9 finished with value: 0.31209236100729576 and parameters: {'max_depth': 43, 'n_estimators': 150, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 16, 'bootstrap': False}. Best is trial 9 with value: 0.31209236100729576.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:10:54,921] Trial 10 finished with value: 0.24338461030724173 and parameters: {'max_depth': 19, 'n_estimators': 400, 'max_features': 'sqrt', 'min_samples_leaf': 24, 'min_samples_split': 2, 'bootstrap': True}. Best is trial 9 with value: 0.31209236100729576.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:14:48,948] Trial 11 finished with value: 0.2777159129378258 and parameters: {'max_depth': 49, 'n_estimators': 400, 'max_features': 'sqrt', 'min_samples_leaf': 22, 'min_samples_split': 16, 'bootstrap': False}. Best is trial 9 with value: 0.31209236100729576.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:18:50,499] Trial 12 finished with value: 0.3126188081438442 and parameters: {'max_depth': 22, 'n_estimators': 350, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 12 with value: 0.3126188081438442.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:23:25,047] Trial 13 finished with value: 0.31518164462796017 and parameters: {'max_depth': 23, 'n_estimators': 400, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:28:35,396] Trial 14 finished with value: 0.3122856962086614 and parameters: {'max_depth': 21, 'n_estimators': 450, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:38:27,673] Trial 15 finished with value: 0.28777499966638825 and parameters: {'max_depth': 10, 'n_estimators': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:41:46,163] Trial 16 finished with value: 0.3076446470542411 and parameters: {'max_depth': 26, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:44:44,627] Trial 17 finished with value: 0.1396087462077826 and parameters: {'max_depth': 4, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 12, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:46:30,743] Trial 18 finished with value: 0.23982752981753244 and parameters: {'max_depth': 15, 'n_estimators': 500, 'max_features': 'log2', 'min_samples_leaf': 12, 'min_samples_split': 24, 'bootstrap': True}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:50:02,444] Trial 19 finished with value: 0.3087513349696269 and parameters: {'max_depth': 23, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:52:49,790] Trial 20 finished with value: 0.27019675445441693 and parameters: {'max_depth': 9, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 12, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 11:58:34,646] Trial 21 finished with value: 0.31356429271947545 and parameters: {'max_depth': 19, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 12:04:51,006] Trial 22 finished with value: 0.31311027996975227 and parameters: {'max_depth': 16, 'n_estimators': 550, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 16, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 12:12:45,472] Trial 23 finished with value: 0.31298618852873233 and parameters: {'max_depth': 14, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 16, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 12:19:32,218] Trial 24 finished with value: 0.31128689718998326 and parameters: {'max_depth': 18, 'n_estimators': 550, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 18, 'bootstrap': False}. Best is trial 13 with value: 0.31518164462796017.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 12:25:58,542] Trial 25 finished with value: 0.32440095935176944 and parameters: {'max_depth': 30, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 25 with value: 0.32440095935176944.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 12:28:46,476] Trial 26 finished with value: 0.26480046996623974 and parameters: {'max_depth': 30, 'n_estimators': 650, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 25 with value: 0.32440095935176944.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 12:35:31,299] Trial 27 finished with value: 0.3216225412376935 and parameters: {'max_depth': 29, 'n_estimators': 450, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 25 with value: 0.32440095935176944.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 12:42:05,922] Trial 28 finished with value: 0.3236040519652922 and parameters: {'max_depth': 30, 'n_estimators': 450, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 25 with value: 0.32440095935176944.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 12:44:04,042] Trial 29 finished with value: 0.10347789604870303 and parameters: {'max_depth': 3, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 25 with value: 0.32440095935176944.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 12:53:28,890] Trial 30 finished with value: 0.32571933918648066 and parameters: {'max_depth': 36, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 30 with value: 0.32571933918648066.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:02:50,852] Trial 31 finished with value: 0.32674276099292926 and parameters: {'max_depth': 50, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 31 with value: 0.32674276099292926.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:11:52,155] Trial 32 finished with value: 0.3261214326862289 and parameters: {'max_depth': 49, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 31 with value: 0.32674276099292926.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:22:45,841] Trial 33 finished with value: 0.3268565611797392 and parameters: {'max_depth': 47, 'n_estimators': 850, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 33 with value: 0.3268565611797392.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:28:09,142] Trial 34 finished with value: 0.30086190430862303 and parameters: {'max_depth': 46, 'n_estimators': 850, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 33 with value: 0.3268565611797392.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:39:30,260] Trial 35 finished with value: 0.3221964615371392 and parameters: {'max_depth': 38, 'n_estimators': 950, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 33 with value: 0.3268565611797392.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:44:51,245] Trial 36 finished with value: 0.3059368870058111 and parameters: {'max_depth': 37, 'n_estimators': 750, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 33 with value: 0.3268565611797392.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:55:44,744] Trial 37 finished with value: 0.32843739784568626 and parameters: {'max_depth': 50, 'n_estimators': 850, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:02:25,827] Trial 38 finished with value: 0.2897637083685253 and parameters: {'max_depth': 46, 'n_estimators': 850, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 4, 'bootstrap': True}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:08:09,005] Trial 39 finished with value: 0.3007140130324958 and parameters: {'max_depth': 47, 'n_estimators': 900, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:13:47,864] Trial 40 finished with value: 0.20846070059434957 and parameters: {'max_depth': 6, 'n_estimators': 800, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:23:59,362] Trial 41 finished with value: 0.3266489791433432 and parameters: {'max_depth': 35, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:34:55,579] Trial 42 finished with value: 0.32652823446455564 and parameters: {'max_depth': 50, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:46:38,286] Trial 43 finished with value: 0.32675319659890945 and parameters: {'max_depth': 42, 'n_estimators': 800, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:54:56,134] Trial 44 finished with value: 0.2898866733801187 and parameters: {'max_depth': 36, 'n_estimators': 800, 'max_features': 'sqrt', 'min_samples_leaf': 16, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:03:34,445] Trial 45 finished with value: 0.2963140876270182 and parameters: {'max_depth': 41, 'n_estimators': 900, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'bootstrap': True}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:11:33,988] Trial 46 finished with value: 0.2812510047089172 and parameters: {'max_depth': 26, 'n_estimators': 800, 'max_features': 'sqrt', 'min_samples_leaf': 20, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:20:06,453] Trial 47 finished with value: 0.3206717694241659 and parameters: {'max_depth': 34, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:33:15,271] Trial 48 finished with value: 0.32508736850893205 and parameters: {'max_depth': 41, 'n_estimators': 900, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 37 with value: 0.32843739784568626.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:35:06,194] Trial 49 finished with value: 0.06891976803360626 and parameters: {'max_depth': 2, 'n_estimators': 950, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'bootstrap': True}. Best is trial 37 with value: 0.32843739784568626.

# %%
optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# Out:
# <ipython-input-7-934d0b211bde>:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# <Axes: title={'center': 'Optimization History Plot'}, xlabel='Trial', ylabel='Objective Value'>

# %%
from optuna.visualization import matplotlib as optuna_matplotlib
import matplotlib.pyplot as plt
optuna.visualization.matplotlib.plot_optimization_history(study_rf)

optuna.visualization.matplotlib.plot_optimization_history(study_rf)
optuna_matplotlib.plot_optimization_history(study_rf)

plt.ylim(0, 1)

# Show the plot
plt.show()
# Out:
# <ipython-input-8-b23cac3d6009>:3: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# <ipython-input-8-b23cac3d6009>:5: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# <ipython-input-8-b23cac3d6009>:6: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna_matplotlib.plot_optimization_history(study_rf)
