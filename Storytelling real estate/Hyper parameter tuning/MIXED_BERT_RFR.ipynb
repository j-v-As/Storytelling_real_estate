# %%
from google.colab import drive
import pandas as pd

# This will prompt for authorization to access your Google Drive
drive.mount('/content/drive')

# Update the file path to the location where you uploaded your CSV in Google Drive
file_path = '/content/drive/My Drive/Thesis/df-BERT_cat.csv'

# Read the CSV file
df = pd.read_csv(file_path)

# Drop the first column (if it's an unwanted index column)
df = df.drop(df.columns[0], axis=1)

# Display the column names
df.columns.tolist()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['numerical_price',
#  'embeddings',
#  'num_bedrooms',
#  'num_rooms',
#  'building_type_Bestaande bouw',
#  'building_type_Nieuwbouw',
#  'building_type_na',
#  'tag_k.k.',
#  'tag_v.o.n.',
#  'house_category_Appartement',
#  'house_category_Bungalow',
#  'house_category_Eengezinswoning',
#  'house_category_Grachtenpand',
#  'house_category_Herenhuis',
#  'house_category_Landhuis',
#  'house_category_Other',
#  'house_category_Unknown',
#  'house_category_Villa',
#  'house_category_Woonboerderij',
#  'house_category_Woonboot',
#  'energy_label_encoded',
#  'size_scaled',
#  'longitude_scaled',
#  'latitude_scaled']

# %%
import pandas as pd
import numpy as np
from ast import literal_eval


df["embeddings"] = df["embeddings"].apply(literal_eval).apply(np.array)

# Separating the target variable and embeddings
x = df["embeddings"]
y = df['numerical_price']

# Dropping the 'ada_embedding_eng' column from df
z = df.drop(["embeddings", "numerical_price"], axis=1)


# Deleting original dataframe for memory purpose
del df

# Explode the embedding arrays into separate columns
x = x.apply(pd.Series)

# Concatenating the exploded embeddings with the rest of the data
concatenated_df = pd.concat([x, z], axis=1).reset_index(drop=True)

# %%
concatenated_df.columns = concatenated_df.columns.astype(str)

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(concatenated_df, y, test_size=0.2, random_state=42)
# Now, sample 10000 instances from the remaining training set for hyperparameter tuning
x_train = x_train.sample(10000, random_state=42)
y_train = y_train.loc[x_train.index]

# %%
# !pip install optuna
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np
import optuna

def Objective_rf_cat(trial):
    # Parameters
    max_depth = trial.suggest_int("max_depth", 2, 50, log=True)
    n_estimators = trial.suggest_int("n_estimators", 100, 1000, step=50)
    max_features = trial.suggest_categorical("max_features", ['log2', 'sqrt',])
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 2, 25, step=2)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 25, step=2)
    bootstrap = trial.suggest_categorical("bootstrap", [True, False])

    rf_params = dict(max_depth=max_depth, n_estimators=n_estimators,
                     max_features=max_features, min_samples_leaf=min_samples_leaf,
                     min_samples_split=min_samples_split, bootstrap=bootstrap)

    clf_rf_opt = RandomForestRegressor(**rf_params, n_jobs=-1)

    # StandardScaler for y
    scaler = StandardScaler()

    # KFold Cross-validation
    kf = KFold(n_splits=5)
    r2_scores = []

    for train_index, test_index in kf.split(x_train):
        X_train_fold, X_test_fold = x_train.iloc[train_index], x_train.iloc[test_index]
        y_train_fold, y_test_fold = y_train.iloc[train_index], y_train.iloc[test_index]

        # Scaling y_train
        y_train_scaled = scaler.fit_transform(np.array(y_train_fold).reshape(-1, 1)).flatten()


        # Fitting the model
        clf_rf_opt.fit(X_train_fold, y_train_scaled)

        # Predicting and inverse transformation
        y_pred_scaled = clf_rf_opt.predict(X_test_fold)
        y_pred = scaler.inverse_transform(np.array(y_pred_scaled).reshape(-1, 1)).flatten()


        # R2 Score
        r2 = r2_score(y_test_fold, y_pred)
        r2_scores.append(r2)

    return float(np.mean(r2_scores))
# Out:
# Collecting optuna
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 4.8 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 7.4 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.0 alembic-1.13.1 colorlog-6.8.0 optuna-3.5.0

# %%
study_rf = optuna.create_study(directions=['maximize'])
study_rf.optimize(Objective_rf_cat, n_trials=50)
# Out:
# [I 2024-01-07 13:08:44,545] A new study created in memory with name: no-name-cc87dd00-1382-4273-86fb-119ba03e60cc
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:10:45,418] Trial 0 finished with value: 0.3680807392278215 and parameters: {'max_depth': 15, 'n_estimators': 150, 'max_features': 'sqrt', 'min_samples_leaf': 16, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 0 with value: 0.3680807392278215.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:12:40,174] Trial 1 finished with value: 0.2804441997300854 and parameters: {'max_depth': 5, 'n_estimators': 200, 'max_features': 'sqrt', 'min_samples_leaf': 14, 'min_samples_split': 12, 'bootstrap': False}. Best is trial 0 with value: 0.3680807392278215.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:18:37,818] Trial 2 finished with value: 0.37655590242883663 and parameters: {'max_depth': 50, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 14, 'min_samples_split': 18, 'bootstrap': True}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:22:46,328] Trial 3 finished with value: 0.27924075528985326 and parameters: {'max_depth': 24, 'n_estimators': 650, 'max_features': 'log2', 'min_samples_leaf': 12, 'min_samples_split': 24, 'bootstrap': False}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:24:46,415] Trial 4 finished with value: 0.13309924285104696 and parameters: {'max_depth': 2, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 18, 'bootstrap': False}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:26:43,225] Trial 5 finished with value: 0.24159862805634064 and parameters: {'max_depth': 23, 'n_estimators': 500, 'max_features': 'log2', 'min_samples_leaf': 16, 'min_samples_split': 18, 'bootstrap': True}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:27:43,969] Trial 6 finished with value: 0.23786431330992164 and parameters: {'max_depth': 4, 'n_estimators': 200, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:30:26,499] Trial 7 finished with value: 0.27765976182724544 and parameters: {'max_depth': 13, 'n_estimators': 450, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:33:46,425] Trial 8 finished with value: 0.22384597076100815 and parameters: {'max_depth': 14, 'n_estimators': 950, 'max_features': 'log2', 'min_samples_leaf': 24, 'min_samples_split': 18, 'bootstrap': True}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:38:14,445] Trial 9 finished with value: 0.3053088982783919 and parameters: {'max_depth': 15, 'n_estimators': 650, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 16, 'bootstrap': False}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:48:24,681] Trial 10 finished with value: 0.35609267530593297 and parameters: {'max_depth': 46, 'n_estimators': 950, 'max_features': 'sqrt', 'min_samples_leaf': 22, 'min_samples_split': 24, 'bootstrap': True}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:49:32,836] Trial 11 finished with value: 0.36151657632422207 and parameters: {'max_depth': 50, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 18, 'min_samples_split': 2, 'bootstrap': True}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:52:18,741] Trial 12 finished with value: 0.32039490704175033 and parameters: {'max_depth': 7, 'n_estimators': 350, 'max_features': 'sqrt', 'min_samples_leaf': 20, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 2 with value: 0.37655590242883663.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 13:55:52,457] Trial 13 finished with value: 0.37761019114327754 and parameters: {'max_depth': 29, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 14, 'min_samples_split': 14, 'bootstrap': True}. Best is trial 13 with value: 0.37761019114327754.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:00:13,041] Trial 14 finished with value: 0.38532769733284744 and parameters: {'max_depth': 33, 'n_estimators': 350, 'max_features': 'sqrt', 'min_samples_leaf': 12, 'min_samples_split': 14, 'bootstrap': True}. Best is trial 14 with value: 0.38532769733284744.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:05:13,222] Trial 15 finished with value: 0.4324027976749161 and parameters: {'max_depth': 28, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 14, 'bootstrap': True}. Best is trial 15 with value: 0.4324027976749161.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:10:59,621] Trial 16 finished with value: 0.43313481412581306 and parameters: {'max_depth': 29, 'n_estimators': 350, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 14, 'bootstrap': True}. Best is trial 16 with value: 0.43313481412581306.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:17:39,587] Trial 17 finished with value: 0.3717653897159054 and parameters: {'max_depth': 9, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 22, 'bootstrap': True}. Best is trial 16 with value: 0.43313481412581306.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:22:49,845] Trial 18 finished with value: 0.43908556228662404 and parameters: {'max_depth': 22, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 18 with value: 0.43908556228662404.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:34:11,564] Trial 19 finished with value: 0.41546008537555795 and parameters: {'max_depth': 19, 'n_estimators': 800, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'bootstrap': True}. Best is trial 18 with value: 0.43908556228662404.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:38:37,534] Trial 20 finished with value: 0.3947088730207482 and parameters: {'max_depth': 10, 'n_estimators': 400, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 18 with value: 0.43908556228662404.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:42:50,029] Trial 21 finished with value: 0.43794685977912373 and parameters: {'max_depth': 33, 'n_estimators': 250, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 12, 'bootstrap': True}. Best is trial 18 with value: 0.43908556228662404.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:47:11,471] Trial 22 finished with value: 0.4400026159599797 and parameters: {'max_depth': 35, 'n_estimators': 250, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:50:47,158] Trial 23 finished with value: 0.4146222539930774 and parameters: {'max_depth': 37, 'n_estimators': 250, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 4, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:53:05,260] Trial 24 finished with value: 0.424326114818422 and parameters: {'max_depth': 20, 'n_estimators': 150, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:54:48,634] Trial 25 finished with value: 0.42494127712578944 and parameters: {'max_depth': 35, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:56:32,168] Trial 26 finished with value: 0.29910604470003427 and parameters: {'max_depth': 38, 'n_estimators': 250, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 14:59:53,601] Trial 27 finished with value: 0.4013218799016117 and parameters: {'max_depth': 19, 'n_estimators': 250, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:04:38,974] Trial 28 finished with value: 0.40009750356985546 and parameters: {'max_depth': 11, 'n_estimators': 400, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:05:51,696] Trial 29 finished with value: 0.3238962499976112 and parameters: {'max_depth': 7, 'n_estimators': 150, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 12, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:08:40,619] Trial 30 finished with value: 0.4155112817209525 and parameters: {'max_depth': 17, 'n_estimators': 200, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 4, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:14:32,615] Trial 31 finished with value: 0.4331449849737211 and parameters: {'max_depth': 26, 'n_estimators': 350, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 12, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:19:35,652] Trial 32 finished with value: 0.4365427214897631 and parameters: {'max_depth': 24, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:24:13,399] Trial 33 finished with value: 0.4250490463173149 and parameters: {'max_depth': 41, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 22 with value: 0.4400026159599797.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:39:32,798] Trial 34 finished with value: 0.4657066191338318 and parameters: {'max_depth': 22, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 34 with value: 0.4657066191338318.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:42:58,370] Trial 35 finished with value: 0.19562944571925742 and parameters: {'max_depth': 3, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 34 with value: 0.4657066191338318.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 15:59:27,181] Trial 36 finished with value: 0.4464095307640674 and parameters: {'max_depth': 22, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 34 with value: 0.4657066191338318.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 16:04:51,439] Trial 37 finished with value: 0.31090137209032676 and parameters: {'max_depth': 22, 'n_estimators': 750, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 34 with value: 0.4657066191338318.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 16:20:28,870] Trial 38 finished with value: 0.42096774319174807 and parameters: {'max_depth': 16, 'n_estimators': 800, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 34 with value: 0.4657066191338318.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 16:23:45,720] Trial 39 finished with value: 0.2832036981285423 and parameters: {'max_depth': 12, 'n_estimators': 550, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 34 with value: 0.4657066191338318.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 16:26:42,378] Trial 40 finished with value: 0.13513822398335673 and parameters: {'max_depth': 2, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 34 with value: 0.4657066191338318.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 16:41:02,715] Trial 41 finished with value: 0.46411167312084034 and parameters: {'max_depth': 30, 'n_estimators': 550, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 34 with value: 0.4657066191338318.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 16:55:19,736] Trial 42 finished with value: 0.4659134241942972 and parameters: {'max_depth': 24, 'n_estimators': 550, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 42 with value: 0.4659134241942972.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 17:07:26,460] Trial 43 finished with value: 0.4436530632384955 and parameters: {'max_depth': 42, 'n_estimators': 550, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 42 with value: 0.4659134241942972.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 17:19:32,087] Trial 44 finished with value: 0.44364749007665855 and parameters: {'max_depth': 46, 'n_estimators': 550, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 42 with value: 0.4659134241942972.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 17:33:37,653] Trial 45 finished with value: 0.4564291780415376 and parameters: {'max_depth': 42, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 42 with value: 0.4659134241942972.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 17:39:01,444] Trial 46 finished with value: 0.3228042867065031 and parameters: {'max_depth': 28, 'n_estimators': 700, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 42 with value: 0.4659134241942972.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 17:49:38,190] Trial 47 finished with value: 0.449204635008699 and parameters: {'max_depth': 15, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 42 with value: 0.4659134241942972.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 17:58:17,718] Trial 48 finished with value: 0.3994127059464952 and parameters: {'max_depth': 13, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 16, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 42 with value: 0.4659134241942972.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 18:05:29,594] Trial 49 finished with value: 0.33669878980883094 and parameters: {'max_depth': 7, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 18, 'min_samples_split': 12, 'bootstrap': False}. Best is trial 42 with value: 0.4659134241942972.

# %%
optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# Out:
# <ipython-input-10-934d0b211bde>:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# <Axes: title={'center': 'Optimization History Plot'}, xlabel='Trial', ylabel='Objective Value'>

# %%
from optuna.visualization import matplotlib as optuna_matplotlib
import matplotlib.pyplot as plt
# Plot the optimization history in a different format
optuna.visualization.matplotlib.plot_optimization_history(study_rf)

optuna_matplotlib.plot_optimization_history(study_rf)

plt.ylim(0, 1)

plt.show()
# Out:
# <ipython-input-11-1eb49e18946d>:4: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# <ipython-input-11-1eb49e18946d>:6: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna_matplotlib.plot_optimization_history(study_rf)
