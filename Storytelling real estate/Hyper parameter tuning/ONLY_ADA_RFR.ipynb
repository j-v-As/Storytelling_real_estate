# %%
from google.colab import drive
import pandas as pd

# This will prompt for authorization to access your Google Drive
drive.mount('/content/drive')

# Update the file path to the location where you uploaded your CSV in Google Drive
file_path = '/content/drive/My Drive/Thesis/df-english.csv'

# Read the CSV file
df = pd.read_csv(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Assuming df is your original DataFrame
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from ast import literal_eval


# Convert the 'ada_embedding_eng' column to a list of arrays if they are not already
df["ada_embedding_eng"] = df["ada_embedding_eng"].apply(literal_eval).apply(np.array)

x = df["ada_embedding_eng"]
y = df['numerical_price']
x = x.apply(pd.Series)
# First split: separate out a test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Now, sample 10000 instances from the remaining training set for hyperparameter tuning
x_train = x_train.sample(10000, random_state=42)
y_train = y_train.loc[x_train.index]


###### deleting original dataframe for memory purpose ####
del df

# %%
x_train = x_train.to_numpy()
x_test = x_test.to_numpy()
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# Ensure y_train and y_test are 1D arrays
# This step is only necessary if y_train or y_test are not already 1D arrays
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

# Check the shapes again after any necessary adjustments
print("Adjusted y_train shape:", y_train.shape)
print("Adjusted y_test shape:", y_test.shape)
# Out:
# Adjusted y_train shape: (10000,)
# Adjusted y_test shape: (14403,)

# %%
# !pip install optuna
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np
import optuna

def Objective_rf(trial):
    # Parameters
    max_depth = trial.suggest_int("max_depth", 2, 50, log=True)
    n_estimators = trial.suggest_int("n_estimators", 100, 1000, step=50)
    max_features = trial.suggest_categorical("max_features", ['log2', 'sqrt',])
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 2, 25, step=2)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 25, step=2)
    bootstrap = trial.suggest_categorical("bootstrap", [True, False])

    rf_params = dict(max_depth=max_depth, n_estimators=n_estimators,
                     max_features=max_features, min_samples_leaf=min_samples_leaf,
                     min_samples_split=min_samples_split, bootstrap=bootstrap)

    clf_rf_opt = RandomForestRegressor(**rf_params, n_jobs=-1)

    # StandardScaler for y
    scaler = StandardScaler()

    # KFold Cross-validation
    kf = KFold(n_splits=5)
    r2_scores = []

    for train_index, test_index in kf.split(x_train):
        X_train_fold, X_test_fold = x_train[train_index], x_train[test_index]
        y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]

        # Scaling y_train
        y_train_scaled = scaler.fit_transform(y_train_fold.reshape(-1, 1)).flatten()

        # Fitting the model
        clf_rf_opt.fit(X_train_fold, y_train_scaled)

        # Predicting and inverse transformation
        y_pred_scaled = clf_rf_opt.predict(X_test_fold)
        y_pred = scaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

        # R2 Score
        r2 = r2_score(y_test_fold, y_pred)
        r2_scores.append(r2)

    return float(np.mean(r2_scores))
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.0)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)

# %%
study_rf = optuna.create_study(directions=['maximize'])
study_rf.optimize(Objective_rf, n_trials=50)
# Out:
# [I 2024-01-06 16:36:55,092] A new study created in memory with name: no-name-842a374a-5b10-443e-85fe-69be116c9508
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:45:56,100] Trial 0 finished with value: 0.19859630549316393 and parameters: {'max_depth': 4, 'n_estimators': 900, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 0 with value: 0.19859630549316393.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:49:13,543] Trial 1 finished with value: 0.28131093692846426 and parameters: {'max_depth': 13, 'n_estimators': 600, 'max_features': 'log2', 'min_samples_leaf': 18, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 1 with value: 0.28131093692846426.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:52:25,333] Trial 2 finished with value: 0.10504362498761702 and parameters: {'max_depth': 2, 'n_estimators': 950, 'max_features': 'sqrt', 'min_samples_leaf': 12, 'min_samples_split': 14, 'bootstrap': True}. Best is trial 1 with value: 0.28131093692846426.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:56:54,873] Trial 3 finished with value: 0.2989820406353746 and parameters: {'max_depth': 8, 'n_estimators': 400, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 3 with value: 0.2989820406353746.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 16:59:50,395] Trial 4 finished with value: 0.3351647456361363 and parameters: {'max_depth': 46, 'n_estimators': 200, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2, 'bootstrap': True}. Best is trial 4 with value: 0.3351647456361363.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:12:51,181] Trial 5 finished with value: 0.31537127054950587 and parameters: {'max_depth': 44, 'n_estimators': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 18, 'min_samples_split': 22, 'bootstrap': True}. Best is trial 4 with value: 0.3351647456361363.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:13:50,030] Trial 6 finished with value: 0.19360437802828642 and parameters: {'max_depth': 6, 'n_estimators': 400, 'max_features': 'log2', 'min_samples_leaf': 24, 'min_samples_split': 14, 'bootstrap': True}. Best is trial 4 with value: 0.3351647456361363.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:36:50,597] Trial 7 finished with value: 0.38122831674407315 and parameters: {'max_depth': 21, 'n_estimators': 900, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 12, 'bootstrap': False}. Best is trial 7 with value: 0.38122831674407315.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:38:39,767] Trial 8 finished with value: 0.10685765337103906 and parameters: {'max_depth': 3, 'n_estimators': 900, 'max_features': 'log2', 'min_samples_leaf': 12, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 7 with value: 0.38122831674407315.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:46:02,027] Trial 9 finished with value: 0.26924309858914486 and parameters: {'max_depth': 6, 'n_estimators': 550, 'max_features': 'sqrt', 'min_samples_leaf': 12, 'min_samples_split': 14, 'bootstrap': False}. Best is trial 7 with value: 0.38122831674407315.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:51:27,583] Trial 10 finished with value: 0.32623476586913425 and parameters: {'max_depth': 20, 'n_estimators': 750, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 7 with value: 0.38122831674407315.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:53:05,207] Trial 11 finished with value: 0.34621494222029 and parameters: {'max_depth': 48, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'bootstrap': True}. Best is trial 7 with value: 0.38122831674407315.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 17:55:31,339] Trial 12 finished with value: 0.34961932224023146 and parameters: {'max_depth': 24, 'n_estimators': 150, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 7 with value: 0.38122831674407315.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:04:25,785] Trial 13 finished with value: 0.39027057272760884 and parameters: {'max_depth': 21, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 13 with value: 0.39027057272760884.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:13:01,031] Trial 14 finished with value: 0.38363817426961155 and parameters: {'max_depth': 20, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 18, 'bootstrap': False}. Best is trial 13 with value: 0.39027057272760884.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:20:30,136] Trial 15 finished with value: 0.366382931638782 and parameters: {'max_depth': 13, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 20, 'bootstrap': False}. Best is trial 13 with value: 0.39027057272760884.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:27:08,530] Trial 16 finished with value: 0.3453239653241963 and parameters: {'max_depth': 27, 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 16, 'min_samples_split': 18, 'bootstrap': False}. Best is trial 13 with value: 0.39027057272760884.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:41:00,365] Trial 17 finished with value: 0.36414608182087693 and parameters: {'max_depth': 13, 'n_estimators': 550, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 24, 'bootstrap': False}. Best is trial 13 with value: 0.39027057272760884.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:43:08,290] Trial 18 finished with value: 0.26724200361980366 and parameters: {'max_depth': 30, 'n_estimators': 400, 'max_features': 'log2', 'min_samples_leaf': 24, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 13 with value: 0.39027057272760884.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:49:09,870] Trial 19 finished with value: 0.36822426456885343 and parameters: {'max_depth': 16, 'n_estimators': 250, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 18, 'bootstrap': False}. Best is trial 13 with value: 0.39027057272760884.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 18:57:37,438] Trial 20 finished with value: 0.3362649468455317 and parameters: {'max_depth': 9, 'n_estimators': 450, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 13 with value: 0.39027057272760884.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 19:17:44,138] Trial 21 finished with value: 0.38880879544470853 and parameters: {'max_depth': 19, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 13 with value: 0.39027057272760884.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 19:36:53,413] Trial 22 finished with value: 0.39165703136472063 and parameters: {'max_depth': 30, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 22 with value: 0.39165703136472063.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 19:56:03,081] Trial 23 finished with value: 0.3911521045353028 and parameters: {'max_depth': 30, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 22 with value: 0.39165703136472063.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 20:13:50,236] Trial 24 finished with value: 0.37288336617077683 and parameters: {'max_depth': 33, 'n_estimators': 750, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 22 with value: 0.39165703136472063.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 20:31:45,565] Trial 25 finished with value: 0.3887431459323322 and parameters: {'max_depth': 31, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 22 with value: 0.39165703136472063.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 20:36:03,275] Trial 26 finished with value: 0.3058220914138122 and parameters: {'max_depth': 36, 'n_estimators': 700, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 22 with value: 0.39165703136472063.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 20:52:12,370] Trial 27 finished with value: 0.35182183410437745 and parameters: {'max_depth': 10, 'n_estimators': 800, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 22 with value: 0.39165703136472063.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 21:02:38,928] Trial 28 finished with value: 0.3469563993184055 and parameters: {'max_depth': 39, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 16, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 22 with value: 0.39165703136472063.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 21:20:35,150] Trial 29 finished with value: 0.3906519480810502 and parameters: {'max_depth': 26, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 22 with value: 0.39165703136472063.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 21:40:16,034] Trial 30 finished with value: 0.36608248056072845 and parameters: {'max_depth': 17, 'n_estimators': 850, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 22 with value: 0.39165703136472063.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 21:58:03,722] Trial 31 finished with value: 0.3928681209640711 and parameters: {'max_depth': 26, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 22:15:55,731] Trial 32 finished with value: 0.39055658075624977 and parameters: {'max_depth': 27, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 22:32:30,385] Trial 33 finished with value: 0.38243211918124775 and parameters: {'max_depth': 37, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 22:46:41,050] Trial 34 finished with value: 0.37139337209810624 and parameters: {'max_depth': 15, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:08:43,550] Trial 35 finished with value: 0.38969725856418397 and parameters: {'max_depth': 26, 'n_estimators': 800, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:09:36,474] Trial 36 finished with value: 0.07114243267139264 and parameters: {'max_depth': 2, 'n_estimators': 600, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 12, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:18:19,541] Trial 37 finished with value: 0.30645218874385327 and parameters: {'max_depth': 41, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 22, 'min_samples_split': 2, 'bootstrap': True}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:32:26,213] Trial 38 finished with value: 0.38168949624815335 and parameters: {'max_depth': 49, 'n_estimators': 550, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:45:03,203] Trial 39 finished with value: 0.3584931195572724 and parameters: {'max_depth': 24, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-06 23:47:05,612] Trial 40 finished with value: 0.10592903929287215 and parameters: {'max_depth': 3, 'n_estimators': 1000, 'max_features': 'log2', 'min_samples_leaf': 14, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 00:05:05,177] Trial 41 finished with value: 0.39042192580766544 and parameters: {'max_depth': 28, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 00:22:42,958] Trial 42 finished with value: 0.3653101969523919 and parameters: {'max_depth': 11, 'n_estimators': 800, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 00:30:31,940] Trial 43 finished with value: 0.28745867275283316 and parameters: {'max_depth': 7, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 00:47:06,059] Trial 44 finished with value: 0.38038570432077223 and parameters: {'max_depth': 24, 'n_estimators': 650, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 8, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 01:04:29,821] Trial 45 finished with value: 0.36845821011362295 and parameters: {'max_depth': 35, 'n_estimators': 850, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 01:19:04,198] Trial 46 finished with value: 0.371579817766685 and parameters: {'max_depth': 42, 'n_estimators': 600, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 01:37:01,669] Trial 47 finished with value: 0.3812967150271883 and parameters: {'max_depth': 23, 'n_estimators': 700, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 01:41:51,560] Trial 48 finished with value: 0.34742472875536057 and parameters: {'max_depth': 18, 'n_estimators': 600, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 31 with value: 0.3928681209640711.
# /usr/local/lib/python3.10/dist-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 25] and step=2, but the range is not divisible by `step`. It will be replaced by [2, 24].
#   warnings.warn(
# [I 2024-01-07 01:49:22,506] Trial 49 finished with value: 0.33685443718124913 and parameters: {'max_depth': 30, 'n_estimators': 500, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 12, 'bootstrap': True}. Best is trial 31 with value: 0.3928681209640711.

# %%
from optuna.visualization import matplotlib as optuna_matplotlib
import matplotlib.pyplot as plt
# Plot the optimization history in a different format
optuna.visualization.matplotlib.plot_optimization_history(study_rf)

optuna_matplotlib.plot_optimization_history(study_rf)

plt.ylim(0, 1)

plt.show()
# Out:
# <ipython-input-14-1eb49e18946d>:4: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_rf)
# <ipython-input-14-1eb49e18946d>:6: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna_matplotlib.plot_optimization_history(study_rf)
