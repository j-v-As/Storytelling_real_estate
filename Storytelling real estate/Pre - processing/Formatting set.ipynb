# %% [markdown]
# This is the code to process the description into the formatted string
# link to sources and examples used:
# https://codereview.stackexchange.com/questions/173971/converting-number-to-words
# https://stackoverflow.com/questions/8982163/how-do-i-tell-python-to-convert-integers-into-words

# %%
import pandas as pd 
df = pd.read_csv("df-empty.csv")

# %%
import math
def numberToWords(n):
    if not isinstance(n, int):
        raise ValueError("Input must be an integer")

    # Handle negative numbers
    if n < 0:
        return "minus " + numberToWords(-n)

    limit, t = 1000000000000, 0

    # If zero, return 'zero'
    if (n == 0):
        return "zero"

    # Arrays for various number parts
    multiplier = ["", "Trillion", "Billion", "Million", "Thousand"]
    first_twenty = ["", "One", "Two", "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine", "Ten", "Eleven", "Twelve", "Thirteen", "Fourteen", "Fifteen", "Sixteen", "Seventeen", "Eighteen", "Nineteen"]
    tens = ["", "Twenty", "Thirty", "Forty", "Fifty", "Sixty", "Seventy", "Eighty", "Ninety"]

    # If number is less than 20, return the corresponding word
    if (n < 20):
        return first_twenty[n]

    answer = ""
    i = n
    while(i > 0):
        curr_hun = i // limit

        # Adjust for current multiplier
        while (int(curr_hun) == 0):
            i %= limit
            limit /= 1000
            curr_hun = i // limit
            t += 1

        # Add hundreds' place if applicable
        if (int(curr_hun) > 99):
                # Explicitly converting the index to an integer
            hundreds_index = int(curr_hun) // 100
            answer += (first_twenty[hundreds_index] + " Hundred ")
        # Adjust for tens and ones
        curr_hun = int(curr_hun) % 100
        if (int(curr_hun) > 0 and int(curr_hun) < 20):
            answer += (first_twenty[int(curr_hun)] + " ")
        elif (int(curr_hun) % 10 == 0 and int(curr_hun) != 0):
                index = int(int(curr_hun) // 10) - 1
                answer += (tens[index] + " ")
        elif (int(curr_hun) > 19 and int(curr_hun) < 100):
                tens_index = int(int(curr_hun) // 10) - 1
                ones_index = int(int(curr_hun) % 10)
                answer += (tens[tens_index] + " " + first_twenty[ones_index] + " ")

        # Add the current multiplier
        if (t < 4):
            answer += (multiplier[t] + " ")

        i = i % limit
        limit = limit // 1000

    return answer

# %%
numberToWords(int(10970))
# Out:
# 'Ten Million Nine Hundred Seventy Million '

# %%
# Check the data types to confirm the conversion
df.dtypes
# Out:
# Unnamed: 0                     int64
# url                           object
# price                         object
# address                       object
# descrip                       object
# listed_since                  object
# zip_code                      object
# size                          object
# year                          object
# living_area                   object
# kind_of_house                 object
# building_type                 object
# num_of_rooms                  object
# num_of_bathrooms              object
# layout                        object
# energy_label                  object
# insulation                    object
# heating                       object
# ownership                     object
# exteriors                     object
# parking                       object
# date_list                     object
# last_ask_price                object
# last_ask_price_m2             object
# city                          object
# log_id                        object
# num of tokens per descrip      int64
# descrip_en                    object
# numerical_price                int64
# numerical_price_per_m2       float64
# tag                           object
# house_category                object
# living_area_float            float64
# size_float                   float64
# zip_code_4_digits              int64
# postcode                     float64
# latitude                     float64
# longitude                    float64
# num_bedrooms                 float64
# num_rooms                      int32
# energy_label_standard         object
# f_string_descrip              object
# dtype: object

# %%
import pandas as pd



# Function to convert number to words, handling NaN values
def number_to_words(num):
    if pd.notna(num):
        return numberToWords(int(num))
    return "unknown"


df['num_rooms'] = df['num_rooms'].fillna(df['num_rooms'].median())
df['size_float'] = df['size_float'].fillna(df['size_float'].median())
df['num_rooms'] = df['num_rooms'].astype(int)
df['size_int'] = df['size_float'].astype(int)


# Function to create the description string
def create_description(row):
    city = row["city"]
    num_rooms = number_to_words(row["num_rooms"])
    space_float = number_to_words(row["size_int"])
    descrip = row["descrip_en"]
    energy = row["energy_label_standard"]
    return f"The house, located in {city}, offers a spacious {space_float} square meters area and features {num_rooms} rooms. It has an energy efficiency rating of '{energy}'. Full description: {descrip}"


# Apply the function to each row
df["f_string_descrip"] = df.apply(create_description, axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://www.funda.nl/koop/aalsmeer/appartement...
# 1           1  https://www.funda.nl/koop/aalsmeer/huis-421002...
# 2           2  https://www.funda.nl/koop/aalsmeer/huis-429389...
# 3           3  https://www.funda.nl/koop/aalsmeer/appartement...
# 4           4  https://www.funda.nl/koop/aalsmeer/huis-429389...
#
#               price                            address  \
# 0  € 403.000 v.o.n.  Appartementen type F (Bouwnr. 77)
# 1    € 589.000 k.k.                       Boomgaard 37
# 2  € 774.500 v.o.n.          Verandawoning (Bouwnr. 7)
# 3  € 403.000 v.o.n.  Appartementen Type E (Bouwnr. 64)
# 4  € 774.500 v.o.n.             Herenhuis (Bouwnr. 22)
#
#                                              descrip listed_since  \
# 0  De Tuinen van  Hornmeer  - appartementen  IN V...         2024
# 1  Wat een fijne  en  energiezuinige eengezinswon...         2006
# 2  De Tuinen van  Hornmeer  - IN  VERKOOP  De omg...         2023
# 3  De Tuinen van  Hornmeer  - appartementen  IN V...         2024
# 4  De Tuinen van  Hornmeer  - IN  VERKOOP  De omg...         2022
#
#                             zip_code    size  year living_area  ...  \
# 0   1431 WE Aalsmeer        Hornmeer   81 m²  2024       81 m²  ...
# 1  1432 LC Aalsmeer        Oosteinde  108 m²  2006      108 m²  ...
# 2   1431 WE Aalsmeer        Hornmeer  202 m²  2023      202 m²  ...
# 3   1431 WE Aalsmeer        Hornmeer   84 m²  2024       84 m²  ...
# 4   1431 WE Aalsmeer        Hornmeer  190 m²  2022      190 m²  ...
#
#   size_float zip_code_4_digits postcode   latitude longitude num_bedrooms  \
# 0       81.0              1431   1431.0  52.250582  4.735323          2.0
# 1      108.0              1432   1432.0  52.280207  4.793252          5.0
# 2      202.0              1431   1431.0  52.250582  4.735323          3.0
# 3       84.0              1431   1431.0  52.250582  4.735323          2.0
# 4      190.0              1431   1431.0  52.250582  4.735323          5.0
#
#   num_rooms energy_label_standard  \
# 0         3                    na
# 1         6                     A
# 2         5                    na
# 3         3                    na
# 4         7                    na
#
#                                     f_string_descrip size_int
# 0  The house is in: aalsmeer with this amount of ...       81
# 1  The house is in: aalsmeer with this amount of ...      108
# 2  The house is in: aalsmeer with this amount of ...      202
# 3  The house is in: aalsmeer with this amount of ...       84
# 4  The house is in: aalsmeer with this amount of ...      190
#
# [5 rows x 43 columns]

# %%
df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://www.funda.nl/koop/aalsmeer/appartement...
# 1           1  https://www.funda.nl/koop/aalsmeer/huis-421002...
# 2           2  https://www.funda.nl/koop/aalsmeer/huis-429389...
# 3           3  https://www.funda.nl/koop/aalsmeer/appartement...
# 4           4  https://www.funda.nl/koop/aalsmeer/huis-429389...
#
#               price                            address  \
# 0  € 403.000 v.o.n.  Appartementen type F (Bouwnr. 77)
# 1    € 589.000 k.k.                       Boomgaard 37
# 2  € 774.500 v.o.n.          Verandawoning (Bouwnr. 7)
# 3  € 403.000 v.o.n.  Appartementen Type E (Bouwnr. 64)
# 4  € 774.500 v.o.n.             Herenhuis (Bouwnr. 22)
#
#                                              descrip listed_since  \
# 0  De Tuinen van  Hornmeer  - appartementen  IN V...         2024
# 1  Wat een fijne  en  energiezuinige eengezinswon...         2006
# 2  De Tuinen van  Hornmeer  - IN  VERKOOP  De omg...         2023
# 3  De Tuinen van  Hornmeer  - appartementen  IN V...         2024
# 4  De Tuinen van  Hornmeer  - IN  VERKOOP  De omg...         2022
#
#                             zip_code    size  year living_area  ...  \
# 0   1431 WE Aalsmeer        Hornmeer   81 m²  2024       81 m²  ...
# 1  1432 LC Aalsmeer        Oosteinde  108 m²  2006      108 m²  ...
# 2   1431 WE Aalsmeer        Hornmeer  202 m²  2023      202 m²  ...
# 3   1431 WE Aalsmeer        Hornmeer   84 m²  2024       84 m²  ...
# 4   1431 WE Aalsmeer        Hornmeer  190 m²  2022      190 m²  ...
#
#   size_float zip_code_4_digits postcode   latitude longitude num_bedrooms  \
# 0       81.0              1431   1431.0  52.250582  4.735323          2.0
# 1      108.0              1432   1432.0  52.280207  4.793252          5.0
# 2      202.0              1431   1431.0  52.250582  4.735323          3.0
# 3       84.0              1431   1431.0  52.250582  4.735323          2.0
# 4      190.0              1431   1431.0  52.250582  4.735323          5.0
#
#   num_rooms energy_label_standard  \
# 0         3                    na
# 1         6                     A
# 2         5                    na
# 3         3                    na
# 4         7                    na
#
#                                     f_string_descrip size_int
# 0  The house is in: aalsmeer with this amount of ...       81
# 1  The house is in: aalsmeer with this amount of ...      108
# 2  The house is in: aalsmeer with this amount of ...      202
# 3  The house is in: aalsmeer with this amount of ...       84
# 4  The house is in: aalsmeer with this amount of ...      190
#
# [5 rows x 43 columns]

# %%
# Display the first 10 entries of the 'f_string_descrip' column
with pd.option_context('display.max_colwidth', None):
    print(df['f_string_descrip'].head(10))
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            The house, located in aalsmeer, offers a spacious One Hundred Eight  square meters area and features Six rooms. It has an energy efficiency rating of 'A'. Full description: What a fine and energy ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 7    The house, located in aalsmeer, offers a spacious One Hundred Sixty Three  square meters area and features Six rooms. It has an energy efficiency rating of 'B'. Full description: Detached house with very sunny backyard located on water, garage with private driveway which has loading pole and 5 spacious bedrooms! The house is located in the child-friendly neighborhood Nieuw-Oosteinde on a slow street with no continuous traffic. The neighborhood is located against Amstelveen and near the Amsterdam Forest. In short, a real family home to get involved! **English text below** CLASSIFICATION: Via the spacious hall with meter cupboard, separate toilet with fountain and staircase the living room is accessible. The generous L-shaped sunroom is a relief and gives a "rich" feeling. The amount of glass provides a lot of light and an atmospheric appearance. Through double doors at the rear there is access to the spacious backyard. The garden is located on the northeast, but due to the depth of the garden and free location on the side (South) of the house you have the sun all day. The garage is also accessible from the backyard and there is also a separate walkway which gives access to the front garden. The open kitchen is located at the front and equipped with the following installation equipment: 6-burner stove with oven and extractor hood, sink, dishwasher, fridge and separate freezer, oven/microwave and wine warmer. The living area is located at the rear of the house over the full width. 1st Floor: There are 3 spacious bedrooms and the bathroom. The modern bathroom has a bath, walk-in shower, double sink and toilet. 2nd Floor: 2 spacious bedrooms equipped with custom fitted wardrobes. Separate storage space with washing machine and dryer connection and central heating system. This room is ideal for creating a 2nd bathroom. LOCATION: The young residential area Nieuw Oosteinde is almost located on the border of Aalsmeer and Amstelveen. The residential area consists of a wide variety of houses. The shopping centre with Albert Heijn and Aldi, chemist, deli, optician, hairdresser, solar studio, bakery, health centre and the Brede School are within walking distance of the property. The location near the Amsterdam Forest is ideal for runners, hikers, nature lovers and dog owners. And if you are a water sports enthusiast then you can fully enjoy/on/in the nearby beautiful Westeinderplassen! The house is centrally located to various roads, such as the A4 and the A9 with its direct connection to the A10 (ring Amsterdam) and the provincial road. The nearby public transport options will take you to the bustling Leidseplein, in the heart of Amsterdam. PARTICULARS: - Living area approx. 163 m2 - The house is built in a nice 30s style with plenty of storage space; - Modern kitchen with the following installation equipment: 6-burner stove with oven and extractor hood, sink, dishwasher, fridge and separate freezer, oven/microwave and wine warmer. - Garage with own driveway equipped with loading pole (3 phases group present); - Mechanical ventilation; - Well insulated and equipped with energy label B; - Sufficient parking in front of the door and/or garage; - Possibility to create 2nd bathroom; - Delivery in consultation. *English text** Detached family home with very sunny backyard facing the water, garage with private driveway equipped with charging station and 5 spacious bedrooms! The house is located in the child-friendly Nieuw-Oosteinde neighbourhood on a car-free street with no passing traffic. The neighbourhood is located near Amstelveen and the Amsterdamse Bos. In a nutshell, a real family house to move in immediately! LAYOUT: Through the spacious hall with meter cupboard, separate toilet with washbasin and stays cupboard, the living room is accessible. The spacious L-shaped living room is a relief and gives a "rich" feeling. The amount of glass inserts flow of light and an atmospheric feel. Through double French doors at the rear, there is  ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# Name: f_string_descrip, dtype: object

# %%
df.to_csv("setup_f_description.csv")
